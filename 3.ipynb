# %%
# Autoregressive models are based on the idea that the current value of the series, xt can be explained  as a funciton of p past values, xt-1, xt-2 where p determines the number of steps into the past needed to forecast the current value.As a typical case, recall Example 1.10 in which data were generated using the model

par(mfrow=c(2,1))
plot(arima.sim(list(order=c(1,0,0), ar=.9), n=100), ylab="x", main=expression(AR(1)~~~phi==+.9))
plot(arima.sim(list(order=c(1,0,0), ar=-.9), n=100), ylab="x",
main=(expression(AR(1)~~~phi==-.9)))
# Out:
# Plot with title “AR(1) ~ ~~phi == -0.9”
